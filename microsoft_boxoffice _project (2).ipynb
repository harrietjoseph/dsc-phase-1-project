# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Harriet Joseph
# * Student pace: part time
# * Scheduled project review date/time: 05/02/2023
# * Instructor name: Roselyn Kamau
# * Blog post URL:http://localhost:8888/notebooks/Microsoft_project_phase1/dsc-phase-1-project/microsoft_boxoffice%20_project.ipynb

# %% [markdown]
# # TASK : DATA SCIENCE PROJECT ON THE PEFORMANCE OF BOXOFFICE FILMS TO GIVE ACCURATE INSIGHTS TO THE HEAD OF MICROSOFT NEW MOVIE STUDIO ON WHAT STEPS TO TAKE FOR BETTER PERFOMANCE IN THE BUSINESS
#
# Microsft company plans on creating a new movie studio like other companies that are already in the film making industry,creating original video content. This is a new field that Microsoft wants to explore and therefore as a company they have very little knowledge about it. As a data scientist, my responsibility is to explore on data and find out the best perfoming box office films, so as to give insights to the Head of Microsoft's new movie studio ; to help decide what types of films should be created.

# %% [markdown]
# The columns in this business problem are:(according to the provided data)
#
# * original_title: the original title of the film
# * start_year: the year the film was released
# * runtime_minutes: the duration of the film in minutes
# * genres: the genre(s) of the film
# * averagerating: the average rating of the film based on reviews
# * numvotes: the number of votes the film received
# * studio: the studio that produced the film
# * domestic_gross: the gross revenue generated by the film in the domestic market
# * foreign_gross: the gross revenue generated by the film in the foreign market
# * release_date: the release date of the film
# * movie: the film being referred to
# * production_budget: the budget allocated for the production of the film
# * worldwide_gross: the gross revenue generated by the film worldwide.

# %% [markdown]
# Requirements
# 1. Load the Data with Pandas
# Create a dataframes movie_gross_df, title_bsc_df ,title_rts_df and movie_bdgt_df that represent the four CSV files. Use pandas methods to inspect the shape and other attributes of these dataframes.
#
# 2. Perform Data Cleaning Required
# Identify and handle missing values
# Identify and handle text data requiring cleaning
#
# 3. Perform Data Aggregation and Cleaning Required
# Join the dataframes together
# Identify and handle invalid values
#
# 4. Perform Data Aggregation Required
#
# the questions i'll be answering in this project:
#
# 1. What are the most successful film genres and themes at the box office?
# 2. What is the correlation between column data ?
# 3. What are the characteristics of successful films that the new movie studio should consider?
# 4. What actionable insights can be provided to the head of Microsoft's new movie studio to help them create successful films?

# %% [markdown]
# # 1. Load the Data with Pandas

# %%
#load necessary python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#load data on movies_gross
movies_gross_df = pd.read_csv('bom.movie_gross.csv', index_col = 0)
movies_gross_df.head()
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010

# %%
movies_gross_df.columns
# Out:
# Index(['studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
movies_gross_df.shape
# Out:
# (3387, 4)

# %%
movies_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3387 entries, Toy Story 3 to An Actor Prepares
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studio          3382 non-null   object
#  1   domestic_gross  3359 non-null   float64
#  2   foreign_gross   2037 non-null   object
#  3   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.3+ KB

# %%
#load data on title basics
title_bsc_df = pd.read_csv('title.basics.csv', index_col = 0)
title_bsc_df.head()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres
# tconst
# tt0063540        2013            175.0    Action,Crime,Drama
# tt0066787        2019            114.0       Biography,Drama
# tt0069049        2018            122.0                 Drama
# tt0069204        2018              NaN          Comedy,Drama
# tt0100275        2017             80.0  Comedy,Drama,Fantasy

# %%
title_bsc_df.columns
# Out:
# Index(['primary_title', 'original_title', 'start_year', 'runtime_minutes',
#        'genres'],
#       dtype='object')

# %%
title_bsc_df.shape
# Out:
# (146144, 5)

# %%
title_bsc_df.info
# Out:
# <bound method DataFrame.info of                                          primary_title  \
# tconst
# tt0063540                                    Sunghursh
# tt0066787              One Day Before the Rainy Season
# tt0069049                   The Other Side of the Wind
# tt0069204                              Sabse Bada Sukh
# tt0100275                     The Wandering Soap Opera
# ...                                                ...
# tt9916538                          Kuambil Lagi Hatiku
# tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# tt9916706                              Dankyavar Danka
# tt9916730                                       6 Gunn
# tt9916754               Chico Albuquerque - Revelações
#
#                                         original_title  start_year  \
# tconst
# tt0063540                                    Sunghursh        2013
# tt0066787                              Ashad Ka Ek Din        2019
# ...

# %%
#load data on movie title ratings
title_rts_df = pd.read_csv('title.ratings.csv', index_col = 0)
title_rts_df.head()
# Out:
#             averagerating  numvotes
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20
# tt1043726             4.2     50352
# tt1060240             6.5        21

# %%
title_rts_df.columns
# Out:
# Index(['averagerating', 'numvotes'], dtype='object')

# %%
title_rts_df.shape
# Out:
# (73856, 2)

# %%
title_rts_df.info
# Out:
# <bound method DataFrame.info of             averagerating  numvotes
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20
# tt1043726             4.2     50352
# tt1060240             6.5        21
# ...                   ...       ...
# tt9805820             8.1        25
# tt9844256             7.5        24
# tt9851050             4.7        14
# tt9886934             7.0         5
# tt9894098             6.3       128
#
# [73856 rows x 2 columns]>

# %%
#load data of movie budget
movie_bdgt_df = pd.read_csv('tn.movie_budgets.csv', index_col = 0)
movie_bdgt_df.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %%
movie_bdgt_df.columns
# Out:
# Index(['release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %%
movie_bdgt_df.shape
# Out:
# (5782, 5)

# %%
movie_bdgt_df.info
# Out:
# <bound method DataFrame.info of     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ..           ...                                          ...
# 78  Dec 31, 2018                                       Red 11
# 79   Apr 2, 1999                                    Following
# 80  Jul 13, 2005                Return to the Land of Wonders
# 81  Sep 29, 2015                         A Plague So Pleasant
# 82   Aug 5, 2005                            My Date With Drew
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# ...

# %% [markdown]
# # 2. Perform Data Cleaning Required

# %% [markdown]
# * indentify and handling missing values

# %% [markdown]
# * movies_gross_df

# %%
movies_gross_df.dtypes
# Out:
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
#foreign_gross is numeric ,but dtype is string ,so change its datatype.
movies_gross_df['foreign_gross'] = movies_gross_df['foreign_gross'].str.replace(',','').astype(float)
movies_gross_df['foreign_gross'].dtype
# Out:
# dtype('float64')

# %%
movies_gross_df['foreign_gross'] = pd.to_numeric(movies_gross_df['foreign_gross'])

# %%
movies_gross_df['domestic_gross'] = pd.to_numeric(movies_gross_df['domestic_gross'])

# %%
movies_gross_df.dtypes
# Out:
# studio             object
# domestic_gross    float64
# foreign_gross     float64
# year                int64
# dtype: object

# %%
# identify the missing values in this data
miss = movies_gross_df.isnull().sum().sort_values(ascending = False)

# %%
percentage_miss = (movies_gross_df.isnull().sum() / len(movies_gross_df)).sort_values(ascending = False)

# %%
missing = pd.DataFrame({"Missing Values": miss, "Percentage(%)": percentage_miss})
missing
# Out:
#                 Missing Values  Percentage(%)
# foreign_gross             1350       0.398583
# domestic_gross              28       0.008267
# studio                       5       0.001476
# year                         0       0.000000

# %%
#replace missing values with mean of movies_gross_df['foreign_gross']
movies_gross_df['foreign_gross'].fillna(movies_gross_df['foreign_gross'].mean(), inplace=True)

# %%
#handling the missing values
#drop the rows in which the studio column has missing values
movies_gross_df.dropna(axis = 0, how = 'any', subset = ['studio'], inplace = True)

# %%
#handling the missing values
#drop the rows in which the studio column has missing values
movies_gross_df.dropna(axis = 0, how = 'any', subset = ['domestic_gross'], inplace = True)

# %%
#check if the missing values was successfully removed
movies_gross_df.isnull().sum().sort_values(ascending = False)
# Out:
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
#find out whether there are duplicated values in the movie_gross dataframe
movies_gross_df.duplicated().sum()
# Out:
# 11

# %%
movies_gross_df = movies_gross_df.drop_duplicates()

# %%
movies_gross_df.duplicated().sum()
# Out:
# 0

# %%
movies_gross_df.describe()
# Out:
#        domestic_gross  foreign_gross         year
# count    3.345000e+03   3.345000e+03  3345.000000
# mean     2.886371e+07   7.542335e+07  2013.968311
# std      6.709771e+07   1.070237e+08     2.480103
# min      1.000000e+02   6.000000e+02  2010.000000
# 25%      1.210000e+05   1.220000e+07  2012.000000
# 50%      1.400000e+06   7.487281e+07  2014.000000
# 75%      2.880000e+07   7.487281e+07  2016.000000
# max      9.367000e+08   9.605000e+08  2018.000000

# %% [markdown]
# * the distribution of revenue(foreign_gross n domestic_gross) by studio.

# %%
#value_counts
movies_gross_df["studio"].value_counts()
# Out:
# IFC           164
# Uni.          147
# WB            140
# Fox           136
# Magn.         135
#              ...
# TVC             1
# E1              1
# ELS             1
# PalT            1
# Synergetic      1
# Name: studio, Length: 255, dtype: int64

# %%
# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = movies_gross_df["studio"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of revenue")
ax2.set_ylabel("Count of revenue")
ax1.set_title("Distribution of revenue by studio")
ax2.set_title("Top 5 studios by Count of revenue ");

# %%
sns.boxplot(data=movies_gross_df[['domestic_gross', 'foreign_gross']], orient="h")
# Out:
# <AxesSubplot:>

# %%
movies_gross_df.reset_index()
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3340                                    The Quake       Magn.          6200.0
# 3341                  Edward II (2018 re-release)          FM          4800.0
# 3342                                     El Pacto        Sony          2500.0
# 3343                                     The Swan  Synergetic          2400.0
# 3344                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
movies_gross_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * title_bsc_df

# %%
title_bsc_df.head()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres
# tconst
# tt0063540        2013            175.0    Action,Crime,Drama
# tt0066787        2019            114.0       Biography,Drama
# tt0069049        2018            122.0                 Drama
# tt0069204        2018              NaN          Comedy,Drama
# tt0100275        2017             80.0  Comedy,Drama,Fantasy

# %%
title_bsc_df.dtypes
# Out:
# primary_title       object
# original_title      object
# start_year           int64
# runtime_minutes    float64
# genres              object
# dtype: object

# %%
# identify the missing values in this data
miss = title_bsc_df.isnull().sum().sort_values(ascending = False)

# %%
percentage_miss = (title_bsc_df.isnull().sum() / len(title_bsc_df)).sort_values(ascending = False)

# %%
missing = pd.DataFrame({"Missing Values": miss, "Percentage(%)": percentage_miss})
missing
# Out:
#                  Missing Values  Percentage(%)
# runtime_minutes           31739       0.217176
# genres                     5408       0.037005
# original_title               21       0.000144
# primary_title                 0       0.000000
# start_year                    0       0.000000

# %%
#for genres , drop all rows that have missing values
title_bsc_df.dropna(axis = 0, how = 'any', subset = ['genres'], inplace = True)

# %%
#for genres , drop all rows that have missing values
title_bsc_df.dropna(axis = 0, how = 'any', subset = ['original_title'], inplace = True)

# %%
#for runtime minutes an average time for movies is between (80-100)minutes
title_bsc_df.fillna(value = title_bsc_df['runtime_minutes'].mean(), inplace = True)

# %%
#check if the missing values was successfully removed
title_bsc_df.isnull().sum().sort_values(ascending = False)
# Out:
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# dtype: int64

# %%
title_bsc_df.duplicated().sum()
# Out:
# 109

# %%
title_bsc_df = title_bsc_df.drop_duplicates()

# %%
title_bsc_df.describe()
# Out:
#           start_year  runtime_minutes
# count  140625.000000    140625.000000
# mean     2014.612757        86.265968
# std         2.735207       149.990738
# min      2010.000000         1.000000
# 25%      2012.000000        75.000000
# 50%      2015.000000        86.261556
# 75%      2017.000000        95.000000
# max      2115.000000     51420.000000

# %%
value = title_bsc_df['genres'].value_counts()
value
# Out:
# Documentary                   32148
# Drama                         21464
# Comedy                         9170
# Horror                         4367
# Comedy,Drama                   3519
#                               ...
# Adventure,Music,Mystery           1
# Documentary,Horror,Romance        1
# Sport,Thriller                    1
# Comedy,Sport,Western              1
# Adventure,History,War             1
# Name: genres, Length: 1085, dtype: int64

# %% [markdown]
# * title_rts_df

# %%
title_rts_df.isna().sum()
# Out:
# averagerating    0
# numvotes         0
# dtype: int64

# %%
title_rts_df.duplicated().sum()
# Out:
# 45074

# %%
title_rts_df = title_rts_df.drop_duplicates()

# %%
title_rts_df.duplicated().sum()
# Out:
# 0

# %%
title_rts_df.shape
# Out:
# (28782, 2)

# %% [markdown]
# # 3. Perform Data Aggregation and Cleaning Required Join the dataframes together Identify and handle invalid values

# %%
#merge the title basics dataframe with title ratings dataframe on common index 'tconst'
title_bsc_rts_df = pd.merge(title_bsc_df, title_rts_df, left_index=True, right_index=True)
title_bsc_rts_df
# Out:
#                              primary_title              original_title  \
# tconst
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
# tt0137204                  Joe Finds Grace             Joe Finds Grace
# ...                                    ...                         ...
# tt9904820            American Terror Story       American Terror Story
# tt9904844             Ott Tänak: The Movie        Ott Tänak: The Movie
# tt9905412                            Ottam                       Ottam
# tt9905462                        Pengalila                   Pengalila
# tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
#
#            start_year  runtime_minutes                      genres  \
# tconst
# ...

# %%
#merge the title_bsc_rts dataframe with movie_gross dataframe on 'primary_title' and 'title'
boxoffice_df = pd.merge(title_bsc_rts_df, movies_gross_df, left_on ='primary_title', right_on = 'title')
boxoffice_df
# Out:
#                         primary_title                   original_title  \
# 0                               Wazir                            Wazir
# 1                         On the Road                      On the Road
# 2     The Secret Life of Walter Mitty  The Secret Life of Walter Mitty
# 3         A Walk Among the Tombstones      A Walk Among the Tombstones
# 4                      Jurassic World                   Jurassic World
# ...                               ...                              ...
# 2675               The Spy Gone North                          Gongjak
# 2676           How Long Will I Love U            Chao shi kong tong ju
# 2677                  Helicopter Eela                  Helicopter Eela
# 2678                      Last Letter                   Ni hao, Zhihua
# 2679        Burn the Stage: The Movie        Burn the Stage: The Movie
#
#       start_year  runtime_minutes                   genres  averagerating  \
# ...

# %%
#remove duplicated columns
boxoffice_df.drop(columns = ['original_title', 'year'], axis = 1, inplace = True)

# %%
boxoffice_df['genre']=boxoffice_df['genres'].str.split(",", expand= True)[0]
boxoffice_df['genre'][0]
# Out:
# 'Action'

# %%
boxoffice_df['genre'].value_counts()
# Out:
# Drama          662
# Action         610
# Comedy         571
# Biography      233
# Adventure      209
# Crime          126
# Documentary    105
# Horror          88
# Animation       32
# Thriller        15
# Fantasy         11
# Mystery          7
# Romance          7
# Family           1
# Sport            1
# Music            1
# Sci-Fi           1
# Name: genre, dtype: int64

# %%
#find out the distribution of movie genre

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = boxoffice_df['genre'].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of genres")
ax2.set_ylabel("Count of genres")
ax1.set_title("Distribution of films by genre")
ax2.set_title("Top 5 most produced genres  ");

# %%
cols = ['start_year', 'runtime_minutes', 'averagerating', 'numvotes', 'domestic_gross', 'foreign_gross']
plt.figure(dpi=140)
sns.pairplot(boxoffice_df[cols])
plt.show()

# %%
# Groupby multiple columns
result = boxoffice_df.groupby(['genre','averagerating','foreign_gross', 'domestic_gross'])['genre'].count()
print(result)
# Out:
# genre     averagerating  foreign_gross  domestic_gross
# Action    1.7            7.487281e+07   271000.0          1
#           2.9            7.487281e+07   274000.0          1
#           3.4            7.487281e+07   99600.0           1
#           3.6            7.487281e+07   680000.0          1
#                          8.860000e+07   51700000.0        1
#                                                          ..
# Thriller  5.8            7.487281e+07   400.0             1
#           6.0            7.487281e+07   6900.0            1
#           6.4            5.200000e+03   33500.0           1
#                          3.000000e+05   21100.0           1
#                          7.487281e+07   43100.0           1
# Name: genre, Length: 2669, dtype: int64

# %%
# Groupby multiple columns & multiple aggregations
result = boxoffice_df.groupby('genre').aggregate({'averagerating':'sum','numvotes':'sum', 'domestic_gross':'sum', 'foreign_gross':'sum'})
print(result)
# Out:
#              averagerating  numvotes  domestic_gross  foreign_gross
# genre
# Action              3845.2  78746224    3.755094e+10   7.951476e+10
# Adventure           1364.4  21334224    1.550681e+10   3.234124e+10
# Animation            218.7   1523071    1.016083e+09   3.087092e+09
# Biography           1627.9  14487279    4.489423e+09   1.249124e+10
# Comedy              3561.2  26158293    1.158269e+10   2.854575e+10
# Crime                840.2   8537834    2.087475e+09   6.043687e+09
# Documentary          759.0    656513    4.191920e+08   5.325646e+09
# Drama               4368.1  26147541    7.395507e+09   3.580127e+10
# Family                 6.5       132    1.840000e+05   2.400000e+06
# Fantasy               67.6    219416    4.655251e+08   1.290691e+09
# Horror               477.2   6140578    2.808791e+09   5.068463e+09
# Music                  7.2     15592    3.400000e+06   4.600000e+06
# Mystery               48.6   2020058    3.430980e+08   4.683728e+08
# ...

# %%
import matplotlib.pyplot as plt

result.plot(kind="bar")
plt.xlabel("Genre")
plt.ylabel("sum Box Office")
plt.title("total Box Office by Genre")
plt.show()

# %%
#identifying the high internal revenue genre
# Calculate the average rating for each genre
genre_dgross = boxoffice_df.groupby('genre')['domestic_gross'].mean()

# Sort the genre ratings in descending order
genre_dgross = genre_dgross.sort_values(ascending=False)

# Plot the bar plot
plt.bar(genre_dgross.index, genre_dgross.values)

# Add labels to the x and y axes
plt.xlabel('Genre')
plt.ylabel('domestic_gross')

# Add a title to the plot
plt.title('internal revenue by Genre Bar Plot')
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
#identifying the high foreign revenue genre
# Calculate the average rating for each genre
genre_fgross = boxoffice_df.groupby('genre')['foreign_gross'].mean()

# Sort the genre ratings in descending order
genre_fgross = genre_fgross.sort_values(ascending=False)

# Plot the bar plot
plt.bar(genre_fgross.index, genre_fgross.values)

# Add labels to the x and y axes
plt.xlabel('Genre')
plt.ylabel('foreign_gross')

# Add a title to the plot
plt.title('foreign revenue by Genre Bar Plot')
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %% [markdown]
# # revenue(foreign_gross & domestic_gross)
# * Revenue can greatly affect the production of specific movie genres.
# If a particular genre is consistently generating high revenue, then studios are more likely to invest in producing more movies within that genre. This is because studios want to make money, and they are more likely to fund projects that have a higher likelihood of financial success. On the other hand, if a particular genre is not generating enough revenue, studios may be less likely to invest in producing movies within that genre.

# %%
#identifying the most voted genres
# Calculate the number of votes for each genre
genre_vot = boxoffice_df.groupby('genre')['numvotes'].sum()

# Sort the genre votes in descending order
genre_vot = genre_vot.sort_values(ascending=False)

# Plot the bar plot
plt.bar(genre_vot.index, genre_vot.values)

# Add labels to the x and y axes
plt.xlabel('Genre')
plt.ylabel('Number of Votes')

# Add a title to the plot
plt.title('Number of Votes by Genre Bar Plot')

#rotation of the xlabel values
plt.xticks(rotation=60)

# Show the plot
plt.show()

# %%
#identifying the most rated genres
# Calculate the average rating for each genre
genre_ratings = boxoffice_df.groupby('genre')['averagerating'].mean()

# Sort the genre ratings in descending order
genre_ratings = genre_ratings.sort_values(ascending=False)

# Plot the bar plot
plt.bar(genre_ratings.index, genre_ratings.values)

# Add labels to the x and y axes
plt.xlabel('Genre')
plt.ylabel('Average Rating')

# Add a title to the plot
plt.title('Average Rating by Genre Bar Plot')
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
# Calculate the domestic and foreign revenue for each genre
genre_revenue = boxoffice_df.groupby('genre')[['domestic_gross', 'foreign_gross']].sum()

# Calculate the domestic and foreign revenue for each genre
genre_revenue = boxoffice_df.groupby('genre')[['domestic_gross', 'foreign_gross']].sum()

# Sort the genre revenue in descending order
genre_revenue = genre_revenue.sort_values(by=['domestic_gross', 'foreign_gross'], ascending=False)

# Set the x-axis as the genre names
x = np.arange(len(genre_revenue.index))

# Plot the bar plot for the domestic and foreign revenue
plt.bar(x - 0.2, genre_revenue['domestic_gross'], 0.2, label='Domestic Revenue')
plt.bar(x, genre_revenue['foreign_gross'], 0.2, label='foreign Revenue')

# Add labels to the x and y axes
plt.xlabel('Movie Genre')
plt.ylabel('Revenue (in millions)')

# Add a title to the plot
plt.title('Revenue by Movie Genre Bar Plot (Sorted)')

# Add the genre names as x-axis labels
plt.xticks(x, genre_revenue.index)

# Add a legend to the plot
plt.legend()

# Rotate the x-axis labels to prevent them from overlapping
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
# Calculate the number of rated movies for each studio
studio_ratings = boxoffice_df['studio'].value_counts()

# Sort the studio ratings in descending order
studio_ratings = studio_ratings.sort_values(ascending=False)

# Take the first 20 rows of the studio ratings
studio_ratings = studio_ratings.iloc[:20]

# Set the x-axis as the studio names
x = np.arange(len(studio_ratings.index))

# Plot the bar plot for the number of rated movies
plt.bar(x, studio_ratings.values)

# Add labels to the x and y axes
plt.xlabel('Studio')
plt.ylabel('Number of Rated Movies')

# Add a title to the plot
plt.title('Top 20 Studios by Number of Rated Movies Bar Plot')

# Add the studio names as x-axis labels
plt.xticks(x, studio_ratings.index, rotation=90)

# Show the plot
plt.show()

# %% [markdown]
# # reasons why certain studios may have higher ratings compared to others:
#
# 1. Quality of content: The studio may consistently produce high-quality content that appeals to audiences, resulting in high ratings.
#
# 2. Budget: Studios with larger budgets can afford to produce higher-quality content and hire top talent, leading to higher ratings.
#
# 3. Marketing: A well-executed marketing campaign can help generate positive buzz and attract more viewers, leading to higher ratings.
#
# 4. Niche market: The studio may focus on a specific niche market that appeals to a highly engaged audience, leading to higher ratings.
#
# 5. Collaboration: The studio may have strong partnerships with other studios or production companies, allowing them to access top talent and resources, leading to higher ratings.

# %%
#create a line plot showing the average movie rating and number of votes over time. 
#You can see how the distribution of average movie ratings and number of votes have changed over time 
#by observing the trends in the lines.

# Group the data by release year and calculate the average rating and number of votes for each year
grouped = df.groupby(df['start_year'])['averagerating', 'numvotes'].mean()

# Create the line plot
plt.plot(grouped.index, grouped['averagerating'], label='Average Rating')
plt.plot(grouped.index, grouped['numvotes'], label='Number of Votes')

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Rating / Number of Votes')
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\harri\AppData\Local\Temp\ipykernel_1400\588649264.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped = df.groupby(df['start_year'])['averagerating', 'numvotes'].mean()

# %%
# Plotting line graph of the average rating
boxoffice_df.groupby('start_year')['averagerating'].sum().plot(kind='line')
plt.xlabel("Year")
plt.ylabel("Average Rating")
plt.title("Trend of Average Rating over Time")
plt.show()

# Plotting line graph of the number of votes
boxoffice_df.groupby('start_year')['numvotes'].sum().plot(kind='line')
plt.xlabel("Year")
plt.ylabel("Number of Votes")
plt.title("Trend of Number of Votes over Time")
plt.show()

# Plotting line graph of the domestic gross
boxoffice_df.groupby('start_year')['domestic_gross'].sum().plot(kind='line')
plt.xlabel("Year")
plt.ylabel("Domestic Gross")
plt.title("Trend of Domestic Gross over Time")
plt.show()

# Plotting line graph of the foreign gross
boxoffice_df.groupby('start_year')['foreign_gross'].sum().plot(kind='line')
plt.xlabel("Year")
plt.ylabel("Foreign Gross")
plt.title("Trend of Foreign Gross over Time")
plt.show()

# %% [markdown]
# # why the downtrend overtime
# as observed a bove there is a downtrend overall from 2016
#
# The reason for a downtrend in the start year from 2016 to 2018 for columns such as numvotes, averagerating, foreign_gross, and domestic_gross could be due to several factors. Some possible reasons include:
#
# Changing audience preferences: The tastes and preferences of moviegoers may have changed, leading to a decline in popularity for certain genres.
#
# Increased competition: With the proliferation of streaming services and home entertainment options, there may be more competition for audiences' attention, leading to a decline in box office revenue and ratings.
#
# Economic factors: Economic conditions, such as a recession or changes in consumer spending, may have led to a decline in movie-going.
#
# Changes in the film industry: The film industry may have undergone changes, such as changes in distribution methods or a decline in the number of theaters, that have led to a decline in the popularity of movies.

# %%
#Showing the distribution of the values for each of these columns by genre.

sns.boxplot(x='genre', y='averagerating', data=boxoffice_df)
plt.title('distribution of averagerating by genre')
plt.xticks(rotation=60)
plt.show()

sns.boxplot(x='genre', y='numvotes', data=boxoffice_df)
plt.title('distribution of numvotes by genre')
plt.xticks(rotation=60)
plt.show()

sns.boxplot(x='genre', y='domestic_gross', data=boxoffice_df)
plt.title('distribution of domestic_gross by genre')
plt.xticks(rotation=60)
plt.show()

sns.boxplot(x='genre', y='foreign_gross', data=boxoffice_df)
plt.title('distribution of foreign_gross by genre')
plt.xticks(rotation=60)
plt.show()

# %%
#show the relationship between "foreign_gross" and "domestic_gross" in the data
sns.scatterplot(x='foreign_gross', y='domestic_gross', data=boxoffice_df)
plt.show()

# %% [markdown]
# * the foreign and domestic gross that can be referred as revenue, as shown above, positively correlate.
#
# it means that as the value of one variable increases, the value of the other variable also increases. In other words, there is a positive relationship between the two variables. This could indicate that, for example, a movie that is successful in its domestic market (domestic_gross) is likely to also be successful in foreign markets (foreign_gross), or vice versa.

# %%
#show the relationship between "numvote" and "domestic_gross" in the data
sns.scatterplot(x='numvotes', y='domestic_gross', data=boxoffice_df)
plt.show()

# %%
##show the relationship between numerical columns
sns.pairplot(boxoffice_df, x_vars=['averagerating', 'numvotes', 'runtime_minutes'], y_vars=['domestic_gross', 'foreign_gross'], hue='genre')

# %% [markdown]
# * numvotes is seen to positively correlate  with foreign_gross, domestic_gross.
# So in this case, if the number of votes for a movie increases, it could be expected that the domestic and foreign gross of the movie will also increase. This could indicate that movies that are more popular among audiences tend to generate higher revenue both domestically and internationally. However, it is important to keep in mind that correlation does not imply causation and there could be other factors that contribute to this relationship.

# %% [markdown]
# Revenue can greatly affect the production of specific movie genres.
# If a particular genre is consistently generating high revenue, then studios are more likely to invest in producing more movies within that genre. This is because studios want to make money, and they are more likely to fund projects that have a higher likelihood of financial success. On the other hand, if a particular genre is not generating enough revenue, studios may be less likely to invest in producing movies within that genre. The revenue generated by a movie can be influenced by various factors such as the popularity of the actors, the budget for the production, marketing and advertising efforts, and the overall market demand for the genre.
# we can clearly see that there is a positive correlation between the domestic gross and the budget.

# %% [markdown]
# # conclusion :
#     Based on the trends you have identified, it may be recommended that Microsoft's new movie studio focus on creating films in the popular genres of action, adventure, comedy, drama, and biopic. Additionally, considering the downtrend in foreign and domestic grosses, as well as declining number of votes and average ratings from 2016 to 2018, the studio may want to focus on producing films that have a strong appeal to both domestic and international audiences. Additionally, it may be beneficial to invest in improving the production quality and overall marketability of the films to increase their chances of success. It may also be helpful to regularly analyze box office trends and make adjustments to the studio's strategy as needed to stay competitive.
